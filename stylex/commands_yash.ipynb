# %%
# run the following for installing packages incase takes time also ignore the numpy error thats fine it will install in the end 
# and does not install in 1 go run indiviusally 
# like
# pip install --user --ignore-installed tensorboard
# pip install --user --ignore-installed tensorflow 
# etc 
# !pip install --user --ignore-installed tensorboard tensorflow retry fire torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      76     """
#      77     try:
# ---> 78         coro.send(None)
#      79     except StopIteration as exc:
#      80         return exc.value
#
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3126
#    3127         with self.builtin_trap:
# -> 3128             cell_name = self.compile.cache(
#    3129                 cell, self.execution_count, raw_code=raw_cell
#    3130             )
#
# /opt/conda/lib/python3.9/site-packages/IPython/core/compilerop.py in cache(self, transformed_code, number, raw_code)
#     153             raw_code = transformed_code
#     154
# ...

# %%
# point to correct path for the data currently its set to sub one : /home/jovyan/thesis/thesis_experiment_1/data/Kaggle_FFHQ_Resized_256px/flickrfaceshq-dataset-nvidia-resized-256px/resized_sub/
# change it accordingly,
# set the following to true is cli : def train_from_folder(
        # data='./data/Kaggle_FFHQ_Resized_256px/flickrfaceshq-dataset-nvidia-resized-256px/resized/',
        #data='/home/jovyan/thesis/thesis_experiment_1/data/Kaggle_FFHQ_Resized_256px/flickrfaceshq-dataset-nvidia-resized-256px/resized_sub/',
        #results_dir='./results',
        #models_dir='./models',
        #name='Faces-Resnet-64',  # Name of the experiment.
        #new=True, # <----This one

# %%
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 106
# WARNING: Ignoring invalid distribution -rchvision (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orchvision (/opt/conda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution - (/opt/conda/lib/python3.9/site-packages)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# ...
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# ...
#   Using cached tensorflow-2.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
# ...
#   Using cached retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# ...
#   Using cached fire-0.4.0-py2.py3-none-any.whl
# ...
#   Using cached https://download.pytorch.org/whl/cu116/torch-1.12.0%2Bcu116-cp39-cp39-linux_x86_64.whl (1904.6 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu116/torchvision-0.13.0%2Bcu116-cp39-cp39-linux_x86_64.whl (23.5 MB)
# ...
